# %% [markdown]
# <a href="https://colab.research.google.com/github/SmileCat42/Deep-Learning/blob/main/Lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Labb 7**
#
# Krittaya Tantichaiyakul
#
# 6705500269

# %% [markdown]
# Lab reg
#
# **1	Code และ แสดงผลกราฟของตามที่เรียน แล้วตอบคำถามต่อไปนี้**
#
# **2	Normalization กับ Stanardization ต่างกันอย่างไร**
#
# ตอบ ทั้ง 2 วิธีมีหลักการเดียวกันคือทำทำการแปลงให้ชุดข้อมูลอยู่ในสเกลที่ใกล้เคียงกัน เพื่อให้โมเดลเรียนรู้ได้เสถียรและเร็วขึ้น เพียงแต่ว่า วิธีการ Normalization จะเป็นการทำให้ชุดข้อมูลอยู่ในช่วง 0-1 ในขณะที่ stanardization จะทำให้ข้อมูลเป็นรูปแบบความเบี่ยงเบน โดยที่มีค่าเฉลี่ยกลางเท่ากับ 0 และส่วนเบี่ยงเบนมาตรฐานเท่ากับ 1 ซึ่งเหมาะสำหรับชุดข้อมูลที่มีค่าของฟีเจอร์ที่แกว่งหรือสเกลต่างกันมาก รวมถึงตัวอย่างนี้ด้วย
#
# **3	สมมติ vector v = [100 0.1] จงแสดงว่า ควร normalize หรือไม่**
#
# ตอบ จากโจทย์ให้ค่าเวกเตอร์ v มีค่าสเกลแต่ละฟีเจอร์ที่ค่อนข้างต่างกันมาก ซึ่ง 100 กับ 0.1 ต่างกันถึง 1000 เท่า ดังนั้นถามว่าควร normalize ไหม ควรทำ feature scaling ค่ะ แต่ไม่ใช่วิธี Normalization ควรเป็น Stanardization จึงเหมาะสมกว่า
#
# **4	Linear Regression ต่างกับ logistic Regression ยังไง**
#
# ตอบ Linear Regression ใช้สำหรับทำนายค่าต่อเนื่อง สมการที่มีความสัมพันธ์กัน อย่างเช่นในตัวอย่างนี้ จะเห็นว่าทุกฟีเจอร์ 13 อัน ส่งผลต่อคำตอบหมดเลย ใจขณะที่ Logistic Regression ใช้สำหรับการจำแนกประเภทโดยแปลงผลลัพธ์เชิงเส้นให้เป็นความน่าจะเป็นผ่านฟังก์ชัน sigmoid เป็นค่าเดี่ยว
#
# **5	MSE กับ MAE ต่างกันอย่างไร**
#
# ตอบ เป็นค่าที่ไว้กำกับโมเดลที่ทำนายผิด สำหรับ MAE จะนำค่าผิดพลาดของทุกๆตัวมาเฉลี่ยกันเช่น |10−12| = 2
#
# |20−18| = 2
#
# |30−25| = 5
#
# 𝑀𝐴𝐸=
# (
# 2
# +
# 2
# +
# 5
# )
# /
# 3
# =
# 3
# MAE=(2+2+5)/3=3
#
# 👉 แปลว่าโมเดลพลาดเฉลี่ย 3 หน่วย
#
# แต่สำหรับ MSE จะโฟกัสเป็นเฉพาะตัว ตัวที่ทำผิดหนัก ก็จะลงโทษหนัก
#
# **6	ลอง one leave out CV**
#
# ตอบ Leave-One-Out Cross-Validation เป็นวิธีที่ในแต่ละรอบจะเลือกข้อมูล 1 ตัวอย่างมาเป็น validation (หรือ test) และใช้ข้อมูลที่เหลือทั้งหมดในการฝึกโมเดล จากนั้นคำนวณ error ของตัวอย่างนั้น และนำ error จากทุกรอบมาเฉลี่ยกัน วิธีนี้เหมาะสำหรับชุดข้อมูลขนาดเล็ก
#
# **7	ลอง k = 5 และ 10 พร้อมวิจารณ์ว่าอะไรดีกว่าควรใช้อะไร**
#
# ตอบ k คือจำนวนรอบ หากปรับให้เพิ่มเป็น 10 รอบ หมายความว่า การแบ่งชุดข้อมูลจะแตกต่างไปจากเดิม เท่ากับว่าสัดส่วนของ valid น้อยลง และ train จะมีสัดส่วนที่มากขึ้น ส่งผลให้โมเดลสามารถเรียนรู้ข้อมูลได้หลากหลายมากขึ้น ลดความเอนเอียงมากขึ้น แต่ต้องแลกกับเวลาที่ต้องใช้ในการเทรนและความแปรปรวนมากขึ้นด้วยนั่นเอง

# %% [markdown]
# x-axis แนวแกน x & y-axis แนวแกน y
#
# คือความสัมพันธ์ของการเปลี่ยนของ เมื่อเกิดการกระทำที่ x แล้วจะทำให้ y เปลี่ยนตามไปด้วย เช่นสมการ y=2x+1 ก็จะได้กราฟใดๆมา หากมีการกำหนดค่าให้ x แล้ว y ก็จะมีค่าเปลี่ยนตามไปด้วย ถ้าเป็นในเรื่องนี้ก็ ขนาดของบ้าน อุณหภูมิ อัชญกรรม ส่งผลต่อราคาบ้าน หรือ x=เหตุ y=ผล

# %%
from keras.datasets import boston_housing
(train_x, train_y), (test_x, test_y) = boston_housing.load_data()

# %%
train_x.shape
# Out:
# (404, 13)

# %%
test_x.shape
# Out:
# (102, 13)

# %%
train_x.ndim
# Out:
# 2

# %% [markdown]
# เป็นการทำให้ชุดข้อมูลให้อยู่ในรูป Standardization หรือส่วนเบี่ยงเบนมาตรฐาน โดยมีสูตรว่า train_x - ค่าเฉลี่ย(mean) / ส่วนเบี่ยงเบนมาตรฐาน(std) เราจะได้ผลลัพธ์ออกมาเป็น ส่วนเบี่ยงเบนได้ตั้งแต่ลบ ค่ากลางคือค่าเฉลี่ย = 0 และไปถึงค่าบวก

# %%
def build_model():
  model = models.Sequential()
  model.add(layers.Dense(64, activation='relu', input_shape=(train_x.shape[1],)))

  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop',
  loss='mse',
  metrics=['mae'])
  return model

# %% [markdown]
# ตรง input แต่ละชุดข้อมูลจะไม่เหมือนกันชุดนี้ใช้ (train_x.shape[1],) อีกอันใช้ (10000,) เพื่อต้องการบอกโมเดลว่า ในแต่ละ sample นั้นมีลักษณะอย่างไร เช่น ข้อมูลข่าว แต่ละข่าวจะมี 10000 ฟีเจอร์ ข้อมูลชุดนี้ก็เหมือนกัน (404,13) ถ้าเราไม่ใช้คำสั่ง จะต้องใส่เป็น (13,) เพราะเรามีชุดข้อมูล 404 ชุด แต่ละชุดจะมีฟีเจอร์บอกรายละเอียดอยู่ 13 ฟีเจอร์ ดังนั้นการใช้คำสั่ง x.shape[1] จะได้คำตอบเป็น (13,) เท่ากัน อจอย่าหลอกเยอะได้ไหมคะ อิอิ

# %%
import numpy as np
k = 4
num_val_samples = len(train_x) // k
num_epochs = 100
all_scores = []

# %% [markdown]
# # <font color="green">**K-fold Cross-Validation แบบที่ 1**</font>

# %%
from keras import models
from keras import layers

for i in range(k):
  print('processing fold #', i)
  val_data = train_x[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_y[i * num_val_samples: (i + 1) * num_val_samples]

  partial_train_data = np.concatenate( [train_x[:i * num_val_samples],
  train_x[(i + 1) * num_val_samples:]],axis=0)
  partial_train_targets = np.concatenate( [train_y[:i * num_val_samples],
  train_y[(i + 1) * num_val_samples:]], axis=0)


  model = build_model()
  model.fit(partial_train_data, partial_train_targets, epochs=num_epochs,
  batch_size = 1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %% [markdown]
# เป็นการแบ่งข้อมูลออกเป็น 4 ท่อน โดยแบ่งให้ valid รอบละ 1 ท่อน อีก 3 ท่อนที่เหลือก็จะเป็น train เมื่อครบ 4 รอบจะได้ valid ในทุกๆรอบออกมา จะทำให้ชุดข้อมูลถูกกระจายใช้งานครบทุกตัว

# %% [markdown]
# # <font color="orange">**K-fold Cross-Validation แบบที่ 2**</font>

# %%
num_epochs = 500
all_mae_histories = []
for i in range(k):
  print('processing fold #', i)
  val_data = train_x[i * num_val_samples: (i + 1) *
  num_val_samples]
  val_targets = train_y[i * num_val_samples: (i + 1) *
  num_val_samples]

  partial_train_targets = np.concatenate(
  [train_y[:i * num_val_samples],
  train_y[(i + 1) * num_val_samples:]],
  axis=0)

  model = build_model()
  history = model.fit(partial_train_data, partial_train_targets,
  validation_data=(val_data, val_targets),
  epochs=num_epochs, batch_size=1, verbose=0)
  mae_history = history.history['val_mae']
  all_mae_histories.append(mae_history)
  average_mae_history = [
  np.mean([x[i] for x in all_mae_histories]) for i in
  range(num_epochs)]
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, len(average_mae_history) + 1),
average_mae_history)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE')
plt.show()

# %% [markdown]
# 500 epoches
#
# ![image.png](data:image/png;base64,...)

# %%
def smooth_curve(points, factor=0.9):
  smoothed_points = []
  for point in points:
    if smoothed_points:

      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))

    else:

      smoothed_points.append(point)

  return smoothed_points

smooth_mae_history = smooth_curve(average_mae_history[10:])
plt.plot(range(1, len(smooth_mae_history) + 1), smooth_mae_history)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE')
plt.show()

# %% [markdown]
# จากเดิมการทำ MAE ด้วยการเฉลี่ย ทำให้กราฟแกว่ง เป็นฟันปลา smooth_curve จึงเข้ามาทำให้กราฟดูสมูทขึ้น ด้วยการตัด 10 epoches แรกออก และใช้ค่า expo เข้ามาจัดการชุดข้อมูล ทำให้ช่วยลด noise แต่ยังรักษาแนวโน้มเดิม

# %%
model = build_model()
model.fit(train_x, train_y,
epochs=30, batch_size=16, verbose=0)
test_mse_score, test_mae_score =model.evaluate(test_x, test_y)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.1495 - mae: 2.7568

# %% [markdown]
# ขั้นตอนสุดท้ายของการสร้างโมเดลอย่างถูกหลัก ใช้ค่า epochs ที่ดีที่สุด
#
# ![image.png](data:image/png;base64,...)
